# %%
import tiktoken

# %%
tokenizer = tiktoken.encoding_for_model("gpt-4o")

# %%
prompt = "Vous êtes un expert en IA agentique. C'est un agent AI"

# %%
tokens = tokenizer.encode(prompt)
print(tokens)
print(f"Le prompt contient {len(tokens)} tokens.")
# Out:
# [29038, 34077, 537, 8333, 469, 59199, 11793, 2222, 13, 363, 6616, 537, 11793, 20837]
# Le prompt contient 14 tokens.

# %%
for token in tokens:
    t = tokenizer.decode_single_token_bytes(token).decode("utf-8")
    print(f"Token: {token}, Caractère: '{t}'")
# Out:
# Token: 29038, Caractère: 'Vous'
# Token: 34077, Caractère: ' êtes'
# Token: 537, Caractère: ' un'
# Token: 8333, Caractère: ' expert'
# Token: 469, Caractère: ' en'
# Token: 59199, Caractère: ' IA'
# Token: 11793, Caractère: ' agent'
# Token: 2222, Caractère: 'ique'
# Token: 13, Caractère: '.'
# Token: 363, Caractère: ' C'
# Token: 6616, Caractère: ''est'
# Token: 537, Caractère: ' un'
# Token: 11793, Caractère: ' agent'
# Token: 20837, Caractère: ' AI'

# %%
from langchain_openai import ChatOpenAI
from dotenv.ipython import load_dotenv
load_dotenv()
# Out:
# o:\enset\hello\Agentic AI\tps\TP1\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1
# True

# %%
llm = ChatOpenAI(model="gpt-4o", temperature=0)

# %%
from IPython.display import Markdown, display

# %%
response = llm.invoke(input = [
    {"role": "system", "content": "Vous êtes un expert en IA Agentique"},
    {"role": "user", "content": "Qu'est-ce que un Agent AI?"}
])
print(display(Markdown(response.content)))
# Out:
# Un agent AI (ou agent intelligent) est un système informatique capable de percevoir son environnement, de prendre des décisions et d'agir de manière autonome pour atteindre des objectifs spécifiques. Les agents AI sont conçus pour simuler certains aspects de l'intelligence humaine, tels que la perception, le raisonnement, l'apprentissage et la prise de décision.
#
# Voici quelques caractéristiques clés des agents AI :
#
# 1. **Perception** : Les agents AI utilisent des capteurs ou des interfaces pour recueillir des informations sur leur environnement. Cela peut inclure des données visuelles, auditives, textuelles, ou d'autres types d'entrées.
#
# 2. **Raisonnement et prise de décision** : Une fois les informations perçues, l'agent utilise des algorithmes pour analyser les données, évaluer différentes options et prendre des décisions basées sur des critères prédéfinis ou appris.
#
# ...

# %%
from langchain_ollama import ChatOllama
#ollama_llm = ChatOllama(model="qwen3.5:cloud", temperature=0)
ollama_llm = ChatOllama(model="llama3.2", temperature=0)

# %%
from langchain.messages import SystemMessage, HumanMessage, AIMessage

# %%
response = ollama_llm.invoke(input = [
    SystemMessage("Vous êtes un expert en IA Agentique"),
    HumanMessage("Qu'est-ce que un Agent AI?")
])

# %%
print(display(Markdown(response.content)))
# Out:
# Un agent AI (Artificial Intelligence) est un programme informatique conçu pour simuler des comportements intelligents, tels que la prise de décision, l'apprentissage et la résolution de problèmes. Les agents AI sont conçus pour interagir avec leur environnement, collecter des informations, prendre des décisions et agir en conséquence.
#
# Les agents AI peuvent être classés en plusieurs catégories, notamment :
#
# 1. **Agents déterministes** : Ces agents suivent une règle ou une logique déterministe pour prendre des décisions et agir.
# 2. **Agents non déterministes** : Ces agents utilisent des algoritmes probabilistes pour prendre des décisions et agir.
# 3. **Agents réfléchis** : Ces agents peuvent réfléchir à leurs actions et à leurs décisions, et peuvent même modifier leurs objectifs ou leurs règles.
#
# Les agents AI peuvent être utilisés dans divers domaines, tels que :
#
# 1. **Robotique** : Les agents AI sont utilisés pour contrôler les robots et les systèmes autonomes.
# ...

# %%
print(display(Markdown(response.content)))
# Out:
# Un agent AI (Artificial Intelligence) est un programme informatique conçu pour simuler des comportements intelligents, tels que la prise de décision, l'apprentissage et la résolution de problèmes. Les agents AI sont conçus pour interagir avec leur environnement, collecter des informations, prendre des décisions et agir en conséquence.
#
# Les agents AI peuvent être classés en plusieurs catégories, notamment :
#
# 1. **Agents déterministes** : Ces agents suivent une règle ou une logique déterministe pour prendre des décisions et agir.
# 2. **Agents non déterministes** : Ces agents utilisent des algoritmes probabilistes pour prendre des décisions et agir.
# 3. **Agents réfléchis** : Ces agents peuvent réfléchir à leurs actions et à leurs décisions, et peuvent même modifier leurs objectifs ou leurs règles.
#
# Les agents AI peuvent être utilisés dans divers domaines, tels que :
#
# 1. **Robotique** : Les agents AI sont utilisés pour contrôler les robots et les systèmes autonomes.
# ...

# %%
llm3 = ChatOpenAI(model="gpt-5.2", temperature=0.5)
llm_with_tools = llm3.bind_tools([
    {   "type": "image_generation","quality": "high"}
])

# %%
generated_image = llm_with_tools.invoke(input = [
    {"role": "user", "content": "Générez une image d'un petit chien avec des lunettes, un costume qui code du JAVA."} ,
])

# %%
from IPython.display import Image 
import base64

# %%
Image(base64.b64decode(generated_image.content_blocks[0]['base64']))

# %%
path = "rag.png"
Image(path)

# %%
llm4 = ChatOpenAI(model="gpt-5.2", temperature=0.5)

# %%
with open(path, "rb") as file:
    image = base64.b64encode(file.read()).decode("utf-8")

# %%
response = llm4.invoke(input = [
    HumanMessage(content=[
        {"type" : "text","text" : "Expliquer moi ce que tu vois dans cette image"},
        {"type" : "image_url" , "image_url" : {"url":f"data:image/png;base64,{image}"}}
        ])
])

# %%
print(display(Markdown(response.content)))
# Out:
# L’image illustre le fonctionnement d’une application **RAG (Retrieval-Augmented Generation)**, c’est‑à‑dire un système qui aide un **LLM** (modèle de langage) à répondre en s’appuyant sur des documents.
#
# Voici ce qu’on y voit, étape par étape :
#
# 1. **Ingestion d’un document (PDF)**
#    - Le **PDF** est d’abord **découpé (Split)** en morceaux appelés **“chunks”** (C1, C2, C3).
#
# 2. **Création d’“embeddings”**
#    - Chaque chunk est transformé en un **vecteur de nombres** (les tableaux avec 0.43, 0.11, 0.76, -0.5, etc.).
#    - Ces vecteurs (“**embeddings**”) représentent le sens du texte et servent à faire de la recherche sémantique.
#
# 3. **Stockage dans une base**
#    - Les embeddings sont enregistrés dans une **base de données** (souvent une base vectorielle).
#
# 4. **Question de l’utilisateur**
#    - L’utilisateur pose une **query** via l’**appli** (User App → RAG App).
#
# 5. **Recherche de contexte**
# ...

# %%
system_message = """
Effectuez une analyse de sentiments basée sur les aspects des avis concernant les ordinateurs portables présentés en entrée.
Chaque avis peut comporter un ou plusieurs des aspects suivants: screen, keybloard et pad.
Pour chaque avis présenté en entrée:
-Identifiez la présence d'au moins un des trois aspects (screen, keybloard, pad).
-Attribuez une polarité de sentiment (positive, negative ou neutral) à chaque aspect. 
Organisez votre réponse dans un objet JSON avec les en-têtes suivants :
-category:[liste des aspects]
-polarity:[liste des polarités correspondantes pour chaque aspect]
Si l'un des aspects n'est pas présent dans l'avis de l'utilisateur, tu supposes que la polarité est neutre 
"""

# %%
llm5 = ChatOpenAI(model="gpt-5.2", temperature=0.5)
response = llm5.invoke(input = [
    SystemMessage(system_message),
    HumanMessage("Avis: J'aime l'écran de ce laptop, mais le clavier mafih maytchaf chouuha et le pad est correct.")
])

# %%
print((response.content))
# Out:
# ```json
# {
#   "category": ["screen", "keybloard", "pad"],
#   "polarity": ["positive", "negative", "neutral"]
# }
# ```

# %%
import json

# %%
raw = response.content.strip()

# Remove Markdown code fences if present
if raw.startswith("```"):
    lines = raw.splitlines()
    lines = lines[1:]  # remove opening ```json or ```
    if lines and lines[-1].strip() == "```":
        lines = lines[:-1]  # remove closing ```
    raw = "\n".join(lines).strip()

r = json.loads(raw)
r
# Out:
# {'category': ['screen', 'keybloard', 'pad'],
#  'polarity': ['positive', 'negative', 'neutral']}

# %%
print(r["category"])
# Out:
# ['screen', 'keybloard', 'pad']

# %%
print(r["polarity"])
# Out:
# ['positive', 'negative', 'neutral']
